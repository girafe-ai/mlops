# %% [markdown]
# ## Autoreload Demo
#
# The `%autoreload` magic automatically reloads modules before executing code,
# so any changes you make to `.py` files are picked up without restarting the kernel.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Now any import from `download.py` will always reflect the latest saved version of the file.
# Try editing `DEFAULT_PACKAGES` or any method in `download.py` — re-running cells below
# will use the updated code automatically.

# %%
# !pip install fire cityscapesscripts

# %%
from download import DEFAULT_PACKAGES, CityscapesDownloader

# %%
print("DEFAULT_PACKAGES:", DEFAULT_PACKAGES)

# %%
downloader = CityscapesDownloader()
print(type(downloader))

# %% [markdown]
# ## Verify autoreload in action
#
# 1. Open `scripts/download.py`
# 2. Change `DEFAULT_PACKAGES` (e.g. add `"leftImg8bit_trainvaltest.zip"`)
# 3. Save the file
# 4. Re-run the cell below — you'll see the updated value without restarting the kernel

# %%
from download import DEFAULT_PACKAGES

print("DEFAULT_PACKAGES after edit:", DEFAULT_PACKAGES)
